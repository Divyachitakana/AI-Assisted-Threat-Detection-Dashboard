# %% [markdown]
# # SQL – GROUP BY
#
# ## Explanation
#
# The `GROUP BY` clause is used to group rows that have the same values in one or more columns. It is commonly used with aggregate functions such as `COUNT()`, `SUM()`, `AVG()`, `MIN()`, and `MAX()` to summarize data.
#
# In this notebook, we will learn how to group data and perform calculations for each group.
#
# ## Prompt
#
# > Explain the SQL GROUP BY clause in simple language for beginners. Show how to group records by a column and use aggregate functions with practical examples.
#
# ## Example

# %%
-- Count the number of students in each city

SELECT City, COUNT(*) AS TotalStudents
FROM Students
GROUP BY City;

-- Find the average age of students in each city

SELECT City, AVG(Age) AS AverageAge
FROM Students
GROUP BY City;

# %% [markdown]
# ## Conclusion
#
# The `GROUP BY` clause groups rows with similar values and is often used with aggregate functions to summarize data. It helps analyze information by categories instead of individual records.
