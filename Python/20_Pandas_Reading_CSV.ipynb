# %% [markdown]
# # Pandas – Reading CSV Files
#
# ## Explanation
#
# CSV files are commonly used to store tabular data. Pandas makes it easy to read and analyze CSV files.
#
# ## Prompt
#
# > Explain how to read a CSV file using Pandas and display the first few rows.
#
# ## Example

# %%
import pandas as pd

# Replace with your own CSV file
df = pd.read_csv("sample.csv")

print(df.head())

# %% [markdown]
# ## Conclusion
#
# Pandas can load CSV files with a single function, making data analysis simple and efficient.
